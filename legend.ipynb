# %%
import matplotlib.pyplot as plt

# Create a Figure and Axes
fig, ax = plt.subplots(figsize = (15, 1))

ax.plot([], [], label='Theory $\mathcal{C}_1$', color = 'tab:red')
ax.plot([], [], label='Theory $\mathcal{C}_2$', color = 'tab:blue')
ax.hist([], label='Simulation $\mathcal{C}_1$', color = 'tab:red', alpha = .5)
ax.hist([], label='Simulation $\mathcal{C}_2$', color = 'tab:blue', alpha = .5)

plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.5), fontsize = 17, fancybox= True, ncol = 4 )

# Hide the axes to only show the legend
ax.set_axis_off()

# Save the plot with only the legend to a PDF file
fig.savefig('legend_1.pdf', bbox_inches='tight')

# Show the legend (optional)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({"text.usetex": True,"font.family": "STIXGeneral"})#,"font.sans-serif": "Helvetica",})
# Create a Figure and Axes
fig, ax = plt.subplots(figsize = (20, 1))

linewidth = 20
s = 3000
alpha = .7

legend_hanles = []
legend_hanles.append(plt.Line2D([], [], label='Theory:', linestyle = 'None'))
legend_hanles.append(plt.Line2D([], [], label='Simulation:', linestyle = 'None'))
legend_hanles.append(plt.Line2D([], [], label='Oracle', color = 'tab:purple', linewidth= linewidth))
legend_hanles.append(plt.scatter([], [], label='Oracle', s = s , marker = 'D', color = 'tab:purple', alpha = .7))
legend_hanles.append(plt.Line2D([], [], label='Optimized', color = 'tab:blue', linewidth= linewidth))
legend_hanles.append(plt.scatter([], [], label='Optimized', s = s,  marker = 'o', color = 'tab:blue', alpha = .7))
legend_hanles.append(plt.Line2D([], [], label='Unbiased', color = 'tab:green', linewidth=linewidth))
legend_hanles.append(plt.scatter([], [], label='Unbiased', s = s,  marker = 'o', color = 'tab:green', alpha = .7))
legend_hanles.append(plt.Line2D([], [], label='Naive', color = 'tab:orange', linewidth= linewidth))
legend_hanles.append(plt.scatter([], [], label='Naive', s = s, marker = '^', color = 'tab:orange', alpha = .7))
plt.legend(handles = legend_hanles, loc='upper center', bbox_to_anchor=(0.5, 0.5), fontsize = 100, fancybox= True, ncol = 5 )

# Hide the axes to only show the legend
ax.set_axis_off()

# Save the plot with only the legend to a PDF file
fig.savefig('legend_3.pdf', bbox_inches='tight')

# Show the legend (optional)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({"text.usetex": True,"font.family": "STIXGeneral"})#,"font.sans-serif": "Helvetica",})

# Create a Figure and Axes
fig, ax = plt.subplots(figsize = (20, 1))

linewidth = 20
s = 3000

legend_hanles = []
legend_hanles.append(plt.Line2D([], [], label='Theory:', linestyle = 'None'))
legend_hanles.append(plt.Line2D([], [], label='Oracle', color = 'tab:purple', linewidth= linewidth))
legend_hanles.append(plt.Line2D([], [], label='Optimized', color = 'tab:green', linewidth= linewidth))
legend_hanles.append(plt.Line2D([], [], label='Unbiased', color = 'tab:blue', linewidth=linewidth))
legend_hanles.append(plt.Line2D([], [], label='Naive', color = 'tab:orange', linewidth= linewidth))
plt.legend(handles = legend_hanles, loc='upper center', bbox_to_anchor=(0.5, 0.5), fontsize = 100, fancybox= True, ncol = 5 )

# Hide the axes to only show the legend
ax.set_axis_off()

# Save the plot with only the legend to a PDF file
fig.savefig('legend_4.pdf', bbox_inches='tight')

# Show the legend (optional)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams.update({"text.usetex": True,"font.family": "STIXGeneral"})#,"font.sans-serif": "Helvetica",})
# Create a Figure and Axes
fig, ax = plt.subplots(figsize = (15, 1))
 
ax.plot([], [], label='Theory $\mathcal{C}_1$', color = 'tab:red')
ax.plot([], [], label='Theory $\mathcal{C}_2$', color = 'tab:blue')
ax.hist([], label='Simulation $\mathcal{C}_1$', color = 'tab:red', alpha = .5)
ax.hist([], label='Simulation $\mathcal{C}_2$', color = 'tab:blue', alpha = .5)
 
legend = plt.legend(loc='upper center', bbox_to_anchor=(0.5, 0.5), fontsize = 17, fancybox= True, ncol = 4 )
 
# Hide the axes to only show the legend
ax.set_axis_off()
 
def export_legend(legend, filename="legend_1.pdf"):
    fig  = legend.figure
    fig.canvas.draw()
    bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
    fig.savefig(filename, dpi="figure", bbox_inches=bbox)
 
# Save the plot with only the legend to a PDF file
#legend.savefig('legend_11.pdf', bbox_inches='tight')
export_legend(legend)
 
# Show the legend (optional)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({"text.usetex": True,"font.family": "STIXGeneral"})#,"font.sans-serif": "Helvetica",})
# Create a Figure and Axes
fig, ax = plt.subplots(figsize = (20, 1))

linewidth = 20
s = 3000
alpha = .7

legend_hanles = []
legend_hanles.append(plt.Line2D([], [], label='Theory:', linestyle = 'None'))
legend_hanles.append(plt.Line2D([], [], label='Simulation:', linestyle = 'None'))
legend_hanles.append(plt.Line2D([], [], label='Oracle', color = 'tab:purple', linewidth= linewidth))
legend_hanles.append(plt.scatter([], [], label='Oracle', s = s , marker = 'D', color = 'tab:purple', alpha = .7))
legend_hanles.append(plt.Line2D([], [], label='LPC', color = 'tab:blue', linewidth= linewidth))
legend_hanles.append(plt.scatter([], [], label='LPC', s = s,  marker = 'o', color = 'tab:blue', alpha = .7))
legend_hanles.append(plt.Line2D([], [], label='Unbiased', color = 'tab:green', linewidth=linewidth))
legend_hanles.append(plt.scatter([], [], label='Unbiased', s = s,  marker = 'o', color = 'tab:green', alpha = .7))
legend_hanles.append(plt.Line2D([], [], label='Naive', color = 'tab:orange', linewidth= linewidth))
legend_hanles.append(plt.scatter([], [], label='Naive', s = s, marker = '^', color = 'tab:orange', alpha = .7))
plt.legend(handles = legend_hanles, loc='upper center', bbox_to_anchor=(0.5, 0.5), fontsize = 100, fancybox= True, ncol = 5 )

# Hide the axes to only show the legend
ax.set_axis_off()

# Save the plot with only the legend to a PDF file
fig.savefig('legend_5.pdf', bbox_inches='tight')

# Show the legend (optional)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({"text.usetex": True,"font.family": "STIXGeneral"})#,"font.sans-serif": "Helvetica",})

# Create a Figure and Axes
fig, ax = plt.subplots(figsize = (20, 1))

linewidth = 5
s = 3000

legend_hanles = []
legend_hanles.append(plt.Line2D([], [], label='Theory:', linestyle = 'None'))
legend_hanles.append(plt.Line2D([], [], linestyle= '-.', label='Oracle', color = 'tab:purple', linewidth= linewidth))
legend_hanles.append(plt.Line2D([], [], label='LPC', color = 'tab:blue', linewidth= linewidth))
legend_hanles.append(plt.Line2D([], [], linestyle = '-.', label='Unbiased', color = 'tab:green', linewidth=linewidth, ))
legend_hanles.append(plt.Line2D([], [], linestyle= '-.', label='Naive', color = 'tab:orange', linewidth= linewidth))
plt.legend(handles = legend_hanles, loc='upper center', bbox_to_anchor=(0.5, 0.5), fontsize = 40, fancybox= True, ncol = 5 )

# Hide the axes to only show the legend
ax.set_axis_off()

# Save the plot with only the legend to a PDF file
fig.savefig('legend_6.pdf', bbox_inches='tight')

# Show the legend (optional)
plt.show()
